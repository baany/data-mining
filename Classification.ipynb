# %%
import pandas as pd
import seaborn as sns
import numpy as np
import xgboost as xgb
from xgboost import XGBClassifier
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
# Out:
# F:\anaconda3\envs\dm\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
df = pd.read_csv("Classification_Loan_Data.csv")
df.head()
# Out:
#    ID  Income_of_Applicant  Income_of_Joint_Applicant  \
# 0   1                 5849                        0.0
# 1   2                 4583                     1508.0
# 2   3                 3000                        0.0
# 3   4                 2583                     2358.0
# 4   5                 6000                        0.0
#
#    Loan_Amount_Requirement  Loan_Amount_Term  Credit_History Gender  \
# 0                      NaN             360.0             1.0   Male
# 1                    128.0             360.0             1.0   Male
# 2                     66.0             360.0             1.0   Male
# 3                    120.0             360.0             1.0   Male
# 4                    141.0             360.0             1.0   Male
#
#   Is_Married No_of_Dependents Level_of_Education IS_Self_Employed  \
# 0         No                0           Graduate               No
# 1        Yes                1           Graduate               No
# 2        Yes                0           Graduate              Yes
# 3        Yes                0       Not Graduate               No
# 4         No                0           Graduate               No
#
#   Area_of_Property Loan_Status
# 0            Urban           Y
# 1            Rural           N
# 2            Urban           Y
# 3            Urban           Y
# 4            Urban           Y

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# #### Missing values

# %%
df.isna().sum()
# Out:
# ID                            0
# Income_of_Applicant           0
# Income_of_Joint_Applicant     0
# Loan_Amount_Requirement      22
# Loan_Amount_Term             14
# Credit_History               50
# Gender                       13
# Is_Married                    3
# No_of_Dependents             15
# Level_of_Education            0
# IS_Self_Employed             32
# Area_of_Property              0
# Loan_Status                   0
# dtype: int64

# %%
# Dropping the missing values for column 'Is_Married' as there are only 3 missing values
df.dropna(subset=['Is_Married'], inplace = True)

# %%
df.Loan_Status.value_counts()
# Out:
# Y    419
# N    192
# Name: Loan_Status, dtype: int64

# %% [markdown]
# #### Here we see that there is significant imbalance between Class 'Y' and Class 'X'
# #### Therefore, we will need to undersample the Majority class to 340 and also oversample the Minority class to 260

# %%
import imblearn
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# #### Using undersample ratio of (192/340)

# %%
under_sampler = RandomUnderSampler(sampling_strategy = (192/340))

# %%
# Segregating into Predictor(X) variables and Target(y) variables
X = df.iloc[:, 0:12]
y = df.iloc[:, 12]
X, y
# Out:
# (      ID  Income_of_Applicant  Income_of_Joint_Applicant  \
#  0      1                 5849                        0.0
#  1      2                 4583                     1508.0
#  2      3                 3000                        0.0
#  3      4                 2583                     2358.0
#  4      5                 6000                        0.0
#  ..   ...                  ...                        ...
#  609  610                 2900                        0.0
#  610  611                 4106                        0.0
#  611  612                 8072                      240.0
#  612  613                 7583                        0.0
#  613  614                 4583                        0.0
#
#       Loan_Amount_Requirement  Loan_Amount_Term  Credit_History  Gender  \
#  0                        NaN             360.0             1.0    Male
#  1                      128.0             360.0             1.0    Male
#  2                       66.0             360.0             1.0    Male
#  3                      120.0             360.0             1.0    Male
#  4                      141.0             360.0             1.0    Male
#  ..                       ...               ...             ...     ...
#  609                     71.0             360.0             1.0  Female
#  610                     40.0             180.0             1.0    Male
#  611                    253.0             360.0             1.0    Male
#  612                    187.0             360.0             1.0    Male
#  613                    133.0             360.0             0.0  Female
#
#      Is_Married No_of_Dependents Level_of_Education IS_Self_Employed  \
#  0           No                0           Graduate               No
#  1          Yes                1           Graduate               No
#  2          Yes                0           Graduate              Yes
#  3          Yes                0       Not Graduate               No
#  4           No                0           Graduate               No
#  ..         ...              ...                ...              ...
#  609         No                0           Graduate               No
#  610        Yes               3+           Graduate               No
#  611        Yes                1           Graduate               No
#  612        Yes                2           Graduate               No
#  613         No                0           Graduate              Yes
#
#      Area_of_Property
#  0              Urban
#  1              Rural
#  2              Urban
#  3              Urban
#  4              Urban
#  ..               ...
#  609            Rural
#  610            Rural
#  611            Urban
#  612            Urban
#  613        Semiurban
#
#  [611 rows x 12 columns],
#  0      Y
#  1      N
#  2      Y
#  3      Y
#  4      Y
#        ..
#  609    Y
#  610    Y
#  611    Y
#  612    Y
#  613    N
#  Name: Loan_Status, Length: 611, dtype: object)

# %%
# Value distribution of Target class after Undersampling

X, y = under_sampler.fit_resample(X, y)
print(y.value_counts())
print('---------------')
X.head()
# Out:
# Y    340
# N    192
# Name: Loan_Status, dtype: int64
# ---------------
#    ID  Income_of_Applicant  Income_of_Joint_Applicant  \
# 0   2                 4583                     1508.0
# 1   8                 3036                     2504.0
# 2  10                12841                    10968.0
# 3  14                 1853                     2840.0
# 4  18                 3510                        0.0
#
#    Loan_Amount_Requirement  Loan_Amount_Term  Credit_History  Gender  \
# 0                    128.0             360.0             1.0    Male
# 1                    158.0             360.0             0.0    Male
# 2                    349.0             360.0             1.0    Male
# 3                    114.0             360.0             1.0    Male
# 4                     76.0             360.0             0.0  Female
#
#   Is_Married No_of_Dependents Level_of_Education IS_Self_Employed  \
# 0        Yes                1           Graduate               No
# 1        Yes               3+           Graduate               No
# 2        Yes                1           Graduate               No
# 3         No                0           Graduate               No
# 4         No                0           Graduate               No
#
#   Area_of_Property
# 0            Rural
# 1        Semiurban
# 2        Semiurban
# 3            Rural
# 4            Urban

# %% [markdown]
# #### Using oversample ratio of (260/340)

# %%
over_sampler = RandomOverSampler(sampling_strategy = (260/340))

# %%
# Value distribution of Target class after Oversampling

X, y = over_sampler.fit_resample(X, y)
print(X.shape)
print('-----')
print(y.shape)
print('-----')
print(y.value_counts())
print('-----')
X.head()
# Out:
# (600, 12)
# -----
# (600,)
# -----
# Y    340
# N    260
# Name: Loan_Status, dtype: int64
# -----
#    ID  Income_of_Applicant  Income_of_Joint_Applicant  \
# 0   2                 4583                     1508.0
# 1   8                 3036                     2504.0
# 2  10                12841                    10968.0
# 3  14                 1853                     2840.0
# 4  18                 3510                        0.0
#
#    Loan_Amount_Requirement  Loan_Amount_Term  Credit_History  Gender  \
# 0                    128.0             360.0             1.0    Male
# 1                    158.0             360.0             0.0    Male
# 2                    349.0             360.0             1.0    Male
# 3                    114.0             360.0             1.0    Male
# 4                     76.0             360.0             0.0  Female
#
#   Is_Married No_of_Dependents Level_of_Education IS_Self_Employed  \
# 0        Yes                1           Graduate               No
# 1        Yes               3+           Graduate               No
# 2        Yes                1           Graduate               No
# 3         No                0           Graduate               No
# 4         No                0           Graduate               No
#
#   Area_of_Property
# 0            Rural
# 1        Semiurban
# 2        Semiurban
# 3            Rural
# 4            Urban

# %%
X['Loan_Status'] = y
df = X.copy(deep = True)

# %%
df.head(15)
# Out:
#     ID  Income_of_Applicant  Income_of_Joint_Applicant  \
# 0    2                 4583                     1508.0
# 1    8                 3036                     2504.0
# 2   10                12841                    10968.0
# 3   14                 1853                     2840.0
# 4   18                 3510                        0.0
# 5   19                 4887                        0.0
# 6   21                 7660                        0.0
# 7   23                 2600                     1911.0
# 8   24                 3365                     1917.0
# 9   25                 3717                     2925.0
# 10  29                 1442                        0.0
# 11  31                 4166                     3369.0
# 12  32                 3167                        0.0
# 13  33                 4692                        0.0
# 14  35                12500                     3000.0
#
#     Loan_Amount_Requirement  Loan_Amount_Term  Credit_History  Gender  \
# 0                     128.0             360.0             1.0    Male
# 1                     158.0             360.0             0.0    Male
# 2                     349.0             360.0             1.0    Male
# 3                     114.0             360.0             1.0    Male
# 4                      76.0             360.0             0.0  Female
# 5                     133.0             360.0             1.0    Male
# 6                     104.0             360.0             0.0    Male
# 7                     116.0             360.0             0.0    Male
# 8                     112.0             360.0             0.0     NaN
# 9                     151.0             360.0             NaN    Male
# 10                     35.0             360.0             1.0    Male
# 11                    201.0             360.0             NaN    Male
# 12                     74.0             360.0             1.0    Male
# 13                    106.0             360.0             1.0    Male
# 14                    320.0             360.0             1.0    Male
#
#    Is_Married No_of_Dependents Level_of_Education IS_Self_Employed  \
# 0         Yes                1           Graduate               No
# 1         Yes               3+           Graduate               No
# 2         Yes                1           Graduate               No
# 3          No                0           Graduate               No
# 4          No                0           Graduate               No
# 5         Yes                0       Not Graduate               No
# 6         Yes                0       Not Graduate               No
# 7         Yes                0       Not Graduate               No
# 8         Yes                2       Not Graduate               No
# 9         Yes                1           Graduate              NaN
# 10         No                0       Not Graduate               No
# 11        Yes                1           Graduate              NaN
# 12         No                0           Graduate               No
# 13         No                1           Graduate              Yes
# 14         No               3+           Graduate               No
#
#    Area_of_Property Loan_Status
# 0             Rural           N
# 1         Semiurban           N
# 2         Semiurban           N
# 3             Rural           N
# 4             Urban           N
# 5             Rural           N
# 6             Urban           N
# 7         Semiurban           N
# 8             Rural           N
# 9         Semiurban           N
# 10            Urban           N
# 11            Urban           N
# 12            Urban           N
# 13            Rural           N
# 14            Rural           N

# %% [markdown]
# ## Missing Value Handling
# ### Methods :-
# #### 1. Imputation
# ####     1. a. Categorical values --> Mode of column
# ####     1. b. Numerical values --> Mean of column
# #### 2. KNN Imputer (Numerical columns)
# ####     2. a. K=1
# ####     2. b. K=2
# ####     2. c. K=3

# %%
print(df.isna().sum())
df.head()
# Out:
# ID                            0
# Income_of_Applicant           0
# Income_of_Joint_Applicant     0
# Loan_Amount_Requirement      24
# Loan_Amount_Term             16
# Credit_History               44
# Gender                       13
# Is_Married                    0
# No_of_Dependents             13
# Level_of_Education            0
# IS_Self_Employed             34
# Area_of_Property              0
# Loan_Status                   0
# dtype: int64
#    ID  Income_of_Applicant  Income_of_Joint_Applicant  \
# 0   2                 4583                     1508.0
# 1   8                 3036                     2504.0
# 2  10                12841                    10968.0
# 3  14                 1853                     2840.0
# 4  18                 3510                        0.0
#
#    Loan_Amount_Requirement  Loan_Amount_Term  Credit_History  Gender  \
# 0                    128.0             360.0             1.0    Male
# 1                    158.0             360.0             0.0    Male
# 2                    349.0             360.0             1.0    Male
# 3                    114.0             360.0             1.0    Male
# 4                     76.0             360.0             0.0  Female
#
#   Is_Married No_of_Dependents Level_of_Education IS_Self_Employed  \
# 0        Yes                1           Graduate               No
# 1        Yes               3+           Graduate               No
# 2        Yes                1           Graduate               No
# 3         No                0           Graduate               No
# 4         No                0           Graduate               No
#
#   Area_of_Property Loan_Status
# 0            Rural           N
# 1        Semiurban           N
# 2        Semiurban           N
# 3            Rural           N
# 4            Urban           N

# %% [markdown]
# ### Imputation with 'Mode' and 'Mean'

# %%
from sklearn.impute import SimpleImputer
si_mean = SimpleImputer(missing_values = np.nan, strategy = 'mean')
si_mode = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')

# %%
# This will find the mode for each column in the dataframe
df.mode().iloc[0]
# Out:
# ID                               255.0
# Income_of_Applicant               2500
# Income_of_Joint_Applicant          0.0
# Loan_Amount_Requirement          110.0
# Loan_Amount_Term                 360.0
# Credit_History                     1.0
# Gender                            Male
# Is_Married                         Yes
# No_of_Dependents                     0
# Level_of_Education            Graduate
# IS_Self_Employed                    No
# Area_of_Property             Semiurban
# Loan_Status                          Y
# Name: 0, dtype: object

# %%
si_data = df.copy(deep = True)
cat_cols = ['Loan_Amount_Term', 'Credit_History', 'Gender', 'No_of_Dependents', 'IS_Self_Employed', 'Level_of_Education', 'Area_of_Property']
si_data[cat_cols] = si_mode.fit_transform(si_data[cat_cols])
knn_data = si_data.copy(deep = True)
num_cols = ['Loan_Amount_Requirement']
si_data[num_cols] = si_mean.fit_transform(si_data[num_cols])

# %%
print(si_data.shape)
si_data.isna().sum()
# Out:
# (600, 13)
# ID                           0
# Income_of_Applicant          0
# Income_of_Joint_Applicant    0
# Loan_Amount_Requirement      0
# Loan_Amount_Term             0
# Credit_History               0
# Gender                       0
# Is_Married                   0
# No_of_Dependents             0
# Level_of_Education           0
# IS_Self_Employed             0
# Area_of_Property             0
# Loan_Status                  0
# dtype: int64

# %% [markdown]
# ### KNN imputation for K = 1,2,3 for all numerical columns

# %%
from sklearn.impute import KNNImputer

knn1_data = knn_data.copy(deep = True)
knn2_data = knn_data.copy(deep = True)
knn3_data = knn_data.copy(deep = True)

# for K = 1
knn1_data[num_cols] = KNNImputer(n_neighbors = 1).fit_transform(knn_data[num_cols])
print(knn1_data.shape)

# for K = 2
knn2_data[num_cols] = KNNImputer(n_neighbors = 2).fit_transform(knn_data[num_cols])
print(knn2_data.shape)

# for K = 3
knn3_data[num_cols] = KNNImputer(n_neighbors = 3).fit_transform(knn_data[num_cols])
print(knn3_data.shape)
# Out:
# (600, 13)
# (600, 13)
# (600, 13)

# %%
# Missing values after KNN imputation

print(knn1_data.isna().sum())
print('-----')
print(knn2_data.isna().sum())
print('-----')
print(knn3_data.isna().sum())
# Out:
# ID                           0
# Income_of_Applicant          0
# Income_of_Joint_Applicant    0
# Loan_Amount_Requirement      0
# Loan_Amount_Term             0
# Credit_History               0
# Gender                       0
# Is_Married                   0
# No_of_Dependents             0
# Level_of_Education           0
# IS_Self_Employed             0
# Area_of_Property             0
# Loan_Status                  0
# dtype: int64
# -----
# ID                           0
# Income_of_Applicant          0
# Income_of_Joint_Applicant    0
# Loan_Amount_Requirement      0
# Loan_Amount_Term             0
# Credit_History               0
# Gender                       0
# Is_Married                   0
# No_of_Dependents             0
# Level_of_Education           0
# IS_Self_Employed             0
# Area_of_Property             0
# Loan_Status                  0
# dtype: int64
# -----
# ID                           0
# Income_of_Applicant          0
# Income_of_Joint_Applicant    0
# Loan_Amount_Requirement      0
# Loan_Amount_Term             0
# Credit_History               0
# Gender                       0
# Is_Married                   0
# No_of_Dependents             0
# Level_of_Education           0
# IS_Self_Employed             0
# Area_of_Property             0
# Loan_Status                  0
# dtype: int64

# %% [markdown]
# ## For categorical variables
# ### Method :- One-hot encoding

# %%
cat_cols
# Out:
# ['Loan_Amount_Term',
#  'Credit_History',
#  'Gender',
#  'No_of_Dependents',
#  'IS_Self_Employed',
#  'Level_of_Education',
#  'Area_of_Property']

# %%
si_data = pd.get_dummies(data = si_data, columns = cat_cols)
si_data
# Out:
# F:\anaconda3\envs\dm\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)
#       ID  Income_of_Applicant  Income_of_Joint_Applicant  \
# 0      2                 4583                     1508.0
# 1      8                 3036                     2504.0
# 2     10                12841                    10968.0
# 3     14                 1853                     2840.0
# 4     18                 3510                        0.0
# ..   ...                  ...                        ...
# 595  601                  416                    41667.0
# 596  582                 1836                    33837.0
# 597  525                 4680                     2087.0
# 598  519                 4683                     1915.0
# 599   23                 2600                     1911.0
#
#      Loan_Amount_Requirement Is_Married Loan_Status  Loan_Amount_Term_12.0  \
# 0                 128.000000        Yes           N                      0
# 1                 158.000000        Yes           N                      0
# 2                 349.000000        Yes           N                      0
# 3                 114.000000         No           N                      0
# 4                  76.000000         No           N                      0
# ..                       ...        ...         ...                    ...
# 595               350.000000         No           N                      0
# 596                90.000000         No           N                      0
# 597               147.366319         No           N                      0
# 598               185.000000         No           N                      0
# 599               116.000000        Yes           N                      0
#
#      Loan_Amount_Term_36.0  Loan_Amount_Term_60.0  Loan_Amount_Term_84.0  ...  \
# 0                        0                      0                      0  ...
# 1                        0                      0                      0  ...
# 2                        0                      0                      0  ...
# 3                        0                      0                      0  ...
# 4                        0                      0                      0  ...
# ..                     ...                    ...                    ...  ...
# 595                      0                      0                      0  ...
# 596                      0                      0                      0  ...
# 597                      0                      0                      0  ...
# 598                      0                      0                      0  ...
# 599                      0                      0                      0  ...
#
#      No_of_Dependents_1  No_of_Dependents_2  No_of_Dependents_3+  \
# 0                     1                   0                    0
# 1                     0                   0                    1
# 2                     1                   0                    0
# 3                     0                   0                    0
# 4                     0                   0                    0
# ..                  ...                 ...                  ...
# 595                   0                   0                    1
# 596                   0                   0                    0
# 597                   0                   0                    0
# 598                   0                   0                    0
# 599                   0                   0                    0
#
#      IS_Self_Employed_No  IS_Self_Employed_Yes  Level_of_Education_Graduate  \
# 0                      1                     0                            1
# 1                      1                     0                            1
# 2                      1                     0                            1
# 3                      1                     0                            1
# 4                      1                     0                            1
# ..                   ...                   ...                          ...
# 595                    1                     0                            1
# 596                    1                     0                            1
# 597                    1                     0                            1
# 598                    1                     0                            1
# 599                    1                     0                            0
#
#      Level_of_Education_Not Graduate  Area_of_Property_Rural  \
# 0                                  0                       1
# 1                                  0                       0
# 2                                  0                       0
# 3                                  0                       1
# 4                                  0                       0
# ..                               ...                     ...
# 595                                0                       0
# 596                                0                       0
# 597                                0                       0
# 598                                0                       0
# 599                                1                       0
#
#      Area_of_Property_Semiurban  Area_of_Property_Urban
# 0                             0                       0
# 1                             1                       0
# 2                             1                       0
# 3                             0                       0
# 4                             0                       1
# ..                          ...                     ...
# 595                           0                       1
# 596                           0                       1
# 597                           1                       0
# 598                           1                       0
# 599                           1                       0
#
# [600 rows x 31 columns]

# %%
knn1_data = pd.get_dummies(data = knn1_data, columns = cat_cols)
knn2_data = pd.get_dummies(data = knn2_data, columns = cat_cols)
knn3_data = pd.get_dummies(data = knn3_data, columns = cat_cols)
# Out:
# F:\anaconda3\envs\dm\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)
# F:\anaconda3\envs\dm\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)
# F:\anaconda3\envs\dm\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %%
# Dropping the ID column as it is of no relevance whatsoever

si_data.drop(['ID'], axis = 1, inplace = True)
knn1_data.drop(['ID'], axis = 1, inplace = True)
knn2_data.drop(['ID'], axis = 1, inplace = True)
knn3_data.drop(['ID'], axis = 1, inplace = True)

# %%
# Converting target variable into binary outputs
si_data['Loan_Status'] = si_data['Loan_Status'].apply(lambda x: 0 if x=='N' else 1)
si_data['Loan_Status'].value_counts()
# Out:
# 1    340
# 0    260
# Name: Loan_Status, dtype: int64

# %%
si_data.head()
# Out:
#    Income_of_Applicant  Income_of_Joint_Applicant  Loan_Amount_Requirement  \
# 0                 4583                     1508.0                    128.0
# 1                 3036                     2504.0                    158.0
# 2                12841                    10968.0                    349.0
# 3                 1853                     2840.0                    114.0
# 4                 3510                        0.0                     76.0
#
#   Is_Married  Loan_Status  Loan_Amount_Term_12.0  Loan_Amount_Term_36.0  \
# 0        Yes            0                      0                      0
# 1        Yes            0                      0                      0
# 2        Yes            0                      0                      0
# 3         No            0                      0                      0
# 4         No            0                      0                      0
#
#    Loan_Amount_Term_60.0  Loan_Amount_Term_84.0  Loan_Amount_Term_120.0  ...  \
# 0                      0                      0                       0  ...
# 1                      0                      0                       0  ...
# 2                      0                      0                       0  ...
# 3                      0                      0                       0  ...
# 4                      0                      0                       0  ...
#
#    No_of_Dependents_1  No_of_Dependents_2  No_of_Dependents_3+  \
# 0                   1                   0                    0
# 1                   0                   0                    1
# 2                   1                   0                    0
# 3                   0                   0                    0
# 4                   0                   0                    0
#
#    IS_Self_Employed_No  IS_Self_Employed_Yes  Level_of_Education_Graduate  \
# 0                    1                     0                            1
# 1                    1                     0                            1
# 2                    1                     0                            1
# 3                    1                     0                            1
# 4                    1                     0                            1
#
#    Level_of_Education_Not Graduate  Area_of_Property_Rural  \
# 0                                0                       1
# 1                                0                       0
# 2                                0                       0
# 3                                0                       1
# 4                                0                       0
#
#    Area_of_Property_Semiurban  Area_of_Property_Urban
# 0                           0                       0
# 1                           1                       0
# 2                           1                       0
# 3                           0                       0
# 4                           0                       1
#
# [5 rows x 30 columns]

# %%
knn1_data['Loan_Status'] = knn1_data['Loan_Status'].apply(lambda x: 0 if x=='N' else 1)
knn2_data['Loan_Status'] = knn2_data['Loan_Status'].apply(lambda x: 0 if x=='N' else 1)
knn3_data['Loan_Status'] = knn3_data['Loan_Status'].apply(lambda x: 0 if x=='N' else 1)
print(knn1_data.head())
print(knn2_data.head())
print(knn3_data.head())
# Out:
#    Income_of_Applicant  Income_of_Joint_Applicant  Loan_Amount_Requirement  \
# 0                 4583                     1508.0                    128.0
# 1                 3036                     2504.0                    158.0
# 2                12841                    10968.0                    349.0
# 3                 1853                     2840.0                    114.0
# 4                 3510                        0.0                     76.0
#
#   Is_Married  Loan_Status  Loan_Amount_Term_12.0  Loan_Amount_Term_36.0  \
# 0        Yes            0                      0                      0
# 1        Yes            0                      0                      0
# 2        Yes            0                      0                      0
# 3         No            0                      0                      0
# 4         No            0                      0                      0
#
#    Loan_Amount_Term_60.0  Loan_Amount_Term_84.0  Loan_Amount_Term_120.0  ...  \
# 0                      0                      0                       0  ...
# 1                      0                      0                       0  ...
# 2                      0                      0                       0  ...
# 3                      0                      0                       0  ...
# 4                      0                      0                       0  ...
#
#    No_of_Dependents_1  No_of_Dependents_2  No_of_Dependents_3+  \
# 0                   1                   0                    0
# 1                   0                   0                    1
# 2                   1                   0                    0
# 3                   0                   0                    0
# 4                   0                   0                    0
#
#    IS_Self_Employed_No  IS_Self_Employed_Yes  Level_of_Education_Graduate  \
# 0                    1                     0                            1
# 1                    1                     0                            1
# 2                    1                     0                            1
# 3                    1                     0                            1
# 4                    1                     0                            1
#
#    Level_of_Education_Not Graduate  Area_of_Property_Rural  \
# 0                                0                       1
# 1                                0                       0
# 2                                0                       0
# 3                                0                       1
# 4                                0                       0
#
#    Area_of_Property_Semiurban  Area_of_Property_Urban
# 0                           0                       0
# 1                           1                       0
# 2                           1                       0
# 3                           0                       0
# 4                           0                       1
#
# [5 rows x 30 columns]
#    Income_of_Applicant  Income_of_Joint_Applicant  Loan_Amount_Requirement  \
# 0                 4583                     1508.0                    128.0
# 1                 3036                     2504.0                    158.0
# 2                12841                    10968.0                    349.0
# 3                 1853                     2840.0                    114.0
# 4                 3510                        0.0                     76.0
#
#   Is_Married  Loan_Status  Loan_Amount_Term_12.0  Loan_Amount_Term_36.0  \
# 0        Yes            0                      0                      0
# 1        Yes            0                      0                      0
# 2        Yes            0                      0                      0
# 3         No            0                      0                      0
# 4         No            0                      0                      0
#
#    Loan_Amount_Term_60.0  Loan_Amount_Term_84.0  Loan_Amount_Term_120.0  ...  \
# 0                      0                      0                       0  ...
# 1                      0                      0                       0  ...
# 2                      0                      0                       0  ...
# 3                      0                      0                       0  ...
# 4                      0                      0                       0  ...
#
#    No_of_Dependents_1  No_of_Dependents_2  No_of_Dependents_3+  \
# 0                   1                   0                    0
# 1                   0                   0                    1
# 2                   1                   0                    0
# 3                   0                   0                    0
# 4                   0                   0                    0
#
#    IS_Self_Employed_No  IS_Self_Employed_Yes  Level_of_Education_Graduate  \
# 0                    1                     0                            1
# 1                    1                     0                            1
# 2                    1                     0                            1
# 3                    1                     0                            1
# 4                    1                     0                            1
#
#    Level_of_Education_Not Graduate  Area_of_Property_Rural  \
# 0                                0                       1
# 1                                0                       0
# 2                                0                       0
# 3                                0                       1
# 4                                0                       0
#
#    Area_of_Property_Semiurban  Area_of_Property_Urban
# 0                           0                       0
# 1                           1                       0
# 2                           1                       0
# 3                           0                       0
# 4                           0                       1
#
# [5 rows x 30 columns]
#    Income_of_Applicant  Income_of_Joint_Applicant  Loan_Amount_Requirement  \
# 0                 4583                     1508.0                    128.0
# 1                 3036                     2504.0                    158.0
# 2                12841                    10968.0                    349.0
# 3                 1853                     2840.0                    114.0
# 4                 3510                        0.0                     76.0
#
#   Is_Married  Loan_Status  Loan_Amount_Term_12.0  Loan_Amount_Term_36.0  \
# 0        Yes            0                      0                      0
# 1        Yes            0                      0                      0
# 2        Yes            0                      0                      0
# 3         No            0                      0                      0
# 4         No            0                      0                      0
#
#    Loan_Amount_Term_60.0  Loan_Amount_Term_84.0  Loan_Amount_Term_120.0  ...  \
# 0                      0                      0                       0  ...
# 1                      0                      0                       0  ...
# 2                      0                      0                       0  ...
# 3                      0                      0                       0  ...
# 4                      0                      0                       0  ...
#
#    No_of_Dependents_1  No_of_Dependents_2  No_of_Dependents_3+  \
# 0                   1                   0                    0
# 1                   0                   0                    1
# 2                   1                   0                    0
# 3                   0                   0                    0
# 4                   0                   0                    0
#
#    IS_Self_Employed_No  IS_Self_Employed_Yes  Level_of_Education_Graduate  \
# 0                    1                     0                            1
# 1                    1                     0                            1
# 2                    1                     0                            1
# 3                    1                     0                            1
# 4                    1                     0                            1
#
#    Level_of_Education_Not Graduate  Area_of_Property_Rural  \
# 0                                0                       1
# 1                                0                       0
# 2                                0                       0
# 3                                0                       1
# 4                                0                       0
#
#    Area_of_Property_Semiurban  Area_of_Property_Urban
# 0                           0                       0
# 1                           1                       0
# 2                           1                       0
# 3                           0                       0
# 4                           0                       1
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Train and Test Split (80:20)

# %%
X_si_data = si_data.drop(['Loan_Status'], axis = 1)
y_si_data = si_data['Loan_Status']
X_train_si_data, X_test_si_data, y_train_si_data, y_test_si_data = train_test_split(X_si_data, y_si_data, test_size=0.2, random_state=9)

# %%
X_knn1 = knn1_data.drop(['Loan_Status'], axis = 1)
y_knn1 = knn1_data['Loan_Status']
X_train_knn1, X_test_knn1, y_train_knn1, y_test_knn1 = train_test_split(X_knn1, y_knn1, test_size=0.2, random_state=42)

# %%
X_knn2 = knn2_data.drop(['Loan_Status'], axis = 1)
y_knn2 = knn2_data['Loan_Status']
X_train_knn2, X_test_knn2, y_train_knn2, y_test_knn2 = train_test_split(X_knn2, y_knn2, test_size=0.2, random_state=21)

# %%
X_knn3 = knn3_data.drop(['Loan_Status'], axis = 1)
y_knn3 = knn3_data['Loan_Status']
X_train_knn3, X_test_knn3, y_train_knn3, y_test_knn3 = train_test_split(X_knn3, y_knn3, test_size=0.2, random_state=66)

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
# Dataframe for storing metrics for different models

df_results = pd.DataFrame(columns = ['Model', 'Accuracy Score', 'Overall F1 Score'])
df_results
# Out:
# Empty DataFrame
# Columns: [Model, Accuracy Score, Overall F1 Score]
# Index: []

# %%
dec_tree = DecisionTreeClassifier()
# Conver 'Is_Married' column to binary class values i.e. 0 or 1
X_train_si_data['Is_Married'] = X_train_si_data['Is_Married'].apply(lambda x: 0 if x=='N' else 1)
X_test_si_data['Is_Married'] = X_test_si_data['Is_Married'].apply(lambda x: 0 if x=='N' else 1)
# X_train_si_data, X_test_si_data, y_train_si_data, y_test_si_data
dec_tree_model = dec_tree.fit(X_train_si_data, y_train_si_data)
y_si_data_pred = dec_tree_model.predict(X_test_si_data)
acc_si_data = accuracy_score(y_test_si_data, y_si_data_pred)
f1_si_data = f1_score(y_test_si_data, y_si_data_pred)
print(classification_report(y_test_si_data, y_si_data_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84        65
#            1       0.80      0.82      0.81        55
#
#     accuracy                           0.82       120
#    macro avg       0.82      0.82      0.82       120
# weighted avg       0.83      0.82      0.83       120

# %%
df_results.loc[len(df_results.index)] = ['Decision Tree - Simple imputed', acc_si_data, f1_si_data]
df_results
# Out:
#                             Model  Accuracy Score  Overall F1 Score
# 0  Decision Tree - Simple imputed           0.825          0.810811

# %%
# Conver 'Is_Married' column to binary class values i.e. 0 or 1
X_train_knn1['Is_Married'] = X_train_knn1['Is_Married'].apply(lambda x: 0 if x=='N' else 1)
X_test_knn1['Is_Married'] = X_test_knn1['Is_Married'].apply(lambda x: 0 if x=='N' else 1)

dec_tree_model_knn1 = dec_tree.fit(X_train_knn1, y_train_knn1)
y_knn1_pred = dec_tree_model_knn1.predict(X_test_knn1)
acc_knn1 = accuracy_score(y_test_knn1, y_knn1_pred)
f1_knn1 = f1_score(y_test_knn1, y_knn1_pred)
print(classification_report(y_test_knn1, y_knn1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73        62
#            1       0.72      0.66      0.68        58
#
#     accuracy                           0.71       120
#    macro avg       0.71      0.71      0.71       120
# weighted avg       0.71      0.71      0.71       120

# %%
df_results.loc[len(df_results.index)] = ['Decision Tree - KNN (k=1)', acc_knn1, f1_knn1]
df_results
# Out:
#                             Model  Accuracy Score  Overall F1 Score
# 0  Decision Tree - Simple imputed        0.825000          0.810811
# 1       Decision Tree - KNN (k=1)        0.708333          0.684685

# %%
# Conver 'Is_Married' column to binary class values i.e. 0 or 1
X_train_knn2['Is_Married'] = X_train_knn2['Is_Married'].apply(lambda x: 0 if x=='N' else 1)
X_test_knn2['Is_Married'] = X_test_knn2['Is_Married'].apply(lambda x: 0 if x=='N' else 1)

dec_tree_model_knn2 = dec_tree.fit(X_train_knn2, y_train_knn2)
y_knn2_pred = dec_tree_model_knn2.predict(X_test_knn2)
acc_knn2 = accuracy_score(y_test_knn2, y_knn2_pred)
f1_knn2 = f1_score(y_test_knn2, y_knn2_pred)
print(classification_report(y_test_knn2, y_knn2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.61      0.68        61
#            1       0.67      0.81      0.73        59
#
#     accuracy                           0.71       120
#    macro avg       0.72      0.71      0.71       120
# weighted avg       0.72      0.71      0.71       120

# %%
df_results.loc[len(df_results.index)] = ['Decision Tree - KNN (k=2)', acc_knn2, f1_knn2]
df_results
# Out:
#                             Model  Accuracy Score  Overall F1 Score
# 0  Decision Tree - Simple imputed        0.825000          0.810811
# 1       Decision Tree - KNN (k=1)        0.708333          0.684685
# 2       Decision Tree - KNN (k=2)        0.708333          0.732824

# %%
# Conver 'Is_Married' column to binary class values i.e. 0 or 1
X_train_knn3['Is_Married'] = X_train_knn3['Is_Married'].apply(lambda x: 0 if x=='N' else 1)
X_test_knn3['Is_Married'] = X_test_knn3['Is_Married'].apply(lambda x: 0 if x=='N' else 1)

dec_tree_model_knn3 = dec_tree.fit(X_train_knn3, y_train_knn3)
y_knn3_pred = dec_tree_model_knn3.predict(X_test_knn3)
acc_knn3 = accuracy_score(y_test_knn3, y_knn3_pred)
f1_knn3 = f1_score(y_test_knn3, y_knn3_pred)
print(classification_report(y_test_knn3, y_knn3_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.63        50
#            1       0.74      0.73      0.73        70
#
#     accuracy                           0.69       120
#    macro avg       0.68      0.68      0.68       120
# weighted avg       0.69      0.69      0.69       120

# %%
df_results.loc[len(df_results.index)] = ['Decision Tree - KNN (k=3)', acc_knn3, f1_knn3]
df_results
# Out:
#                             Model  Accuracy Score  Overall F1 Score
# 0  Decision Tree - Simple imputed        0.825000          0.810811
# 1       Decision Tree - KNN (k=1)        0.708333          0.684685
# 2       Decision Tree - KNN (k=2)        0.708333          0.732824
# 3       Decision Tree - KNN (k=3)        0.691667          0.733813

# %% [markdown]
# ## Logistic Regression Model

# %%
lr = LogisticRegression(max_iter = 7600)

# %%
lr_si = lr.fit(X_train_si_data, y_train_si_data)
y_pred_si = lr_si.predict(X_test_si_data)
acc_lr_si = accuracy_score(y_test_si_data, y_pred_si)
f1_lr_si = f1_score(y_test_si_data, y_pred_si)
print(classification_report(y_test_si_data, y_pred_si))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.52      0.67        65
#            1       0.63      0.96      0.76        55
#
#     accuracy                           0.73       120
#    macro avg       0.79      0.74      0.72       120
# weighted avg       0.80      0.72      0.71       120

# %%
df_results.loc[len(df_results.index)] = ['Logistic Regression - Simple imputed', acc_lr_si, f1_lr_si]
df_results
# Out:
#                                   Model  Accuracy Score  Overall F1 Score
# 0        Decision Tree - Simple imputed        0.825000          0.810811
# 1             Decision Tree - KNN (k=1)        0.708333          0.684685
# 2             Decision Tree - KNN (k=2)        0.708333          0.732824
# 3             Decision Tree - KNN (k=3)        0.691667          0.733813
# 4  Logistic Regression - Simple imputed        0.725000          0.762590

# %%
lr_knn1 = lr.fit(X_train_knn1, y_train_knn1)
y_pred_knn1 = lr_knn1.predict(X_test_knn1)
acc_lr_knn1 = accuracy_score(y_test_knn1, y_pred_knn1)
f1_lr_knn1 = f1_score(y_test_knn1, y_pred_knn1)
print(classification_report(y_test_knn1, y_pred_knn1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.42      0.58        62
#            1       0.61      0.98      0.75        58
#
#     accuracy                           0.69       120
#    macro avg       0.79      0.70      0.67       120
# weighted avg       0.79      0.69      0.67       120

# %%
df_results.loc[len(df_results.index)] = ['Logistic Regression - KNN (k=1)', acc_lr_knn1, f1_lr_knn1]
df_results
# Out:
#                                   Model  Accuracy Score  Overall F1 Score
# 0        Decision Tree - Simple imputed        0.825000          0.810811
# 1             Decision Tree - KNN (k=1)        0.708333          0.684685
# 2             Decision Tree - KNN (k=2)        0.708333          0.732824
# 3             Decision Tree - KNN (k=3)        0.691667          0.733813
# 4  Logistic Regression - Simple imputed        0.725000          0.762590
# 5       Logistic Regression - KNN (k=1)        0.691667          0.754967

# %%
lr_knn2 = lr.fit(X_train_knn2, y_train_knn2)
y_pred_knn2 = lr_knn2.predict(X_test_knn2)
acc_lr_knn2 = accuracy_score(y_test_knn2, y_pred_knn2)
f1_lr_knn2 = f1_score(y_test_knn2, y_pred_knn2)
print(classification_report(y_test_knn2, y_pred_knn2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.48      0.60        61
#            1       0.62      0.88      0.73        59
#
#     accuracy                           0.68       120
#    macro avg       0.71      0.68      0.66       120
# weighted avg       0.71      0.68      0.66       120

# %%
df_results.loc[len(df_results.index)] = ['Logistic Regression - KNN (k=2)', acc_lr_knn2, f1_lr_knn2]
df_results
# Out:
#                                   Model  Accuracy Score  Overall F1 Score
# 0        Decision Tree - Simple imputed        0.825000          0.810811
# 1             Decision Tree - KNN (k=1)        0.708333          0.684685
# 2             Decision Tree - KNN (k=2)        0.708333          0.732824
# 3             Decision Tree - KNN (k=3)        0.691667          0.733813
# 4  Logistic Regression - Simple imputed        0.725000          0.762590
# 5       Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6       Logistic Regression - KNN (k=2)        0.675000          0.727273

# %%
lr_knn3 = lr.fit(X_train_knn3, y_train_knn3)
y_pred_knn3 = lr_knn3.predict(X_test_knn3)
acc_lr_knn3 = accuracy_score(y_test_knn3, y_pred_knn3)
f1_lr_knn3 = f1_score(y_test_knn3, y_pred_knn3)
print(classification_report(y_test_knn3, y_pred_knn3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.42      0.55        50
#            1       0.69      0.93      0.79        70
#
#     accuracy                           0.72       120
#    macro avg       0.75      0.67      0.67       120
# weighted avg       0.74      0.72      0.69       120

# %%
df_results.loc[len(df_results.index)] = ['Logistic Regression - KNN (k=3)', acc_lr_knn3, f1_lr_knn3]
df_results
# Out:
#                                   Model  Accuracy Score  Overall F1 Score
# 0        Decision Tree - Simple imputed        0.825000          0.810811
# 1             Decision Tree - KNN (k=1)        0.708333          0.684685
# 2             Decision Tree - KNN (k=2)        0.708333          0.732824
# 3             Decision Tree - KNN (k=3)        0.691667          0.733813
# 4  Logistic Regression - Simple imputed        0.725000          0.762590
# 5       Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6       Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7       Logistic Regression - KNN (k=3)        0.716667          0.792683

# %% [markdown]
# ## KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5)

# %%
knn_si = knn.fit(X_train_si_data, y_train_si_data)
y_pred_knn_si = knn_si.predict(X_test_si_data)
acc_knn_si = accuracy_score(y_test_si_data, y_pred_knn_si)
f1_knn_si = f1_score(y_test_si_data, y_pred_knn_si)
print(classification_report(y_test_si_data, y_pred_knn_si))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.48      0.54        65
#            1       0.51      0.65      0.58        55
#
#     accuracy                           0.56       120
#    macro avg       0.57      0.57      0.56       120
# weighted avg       0.57      0.56      0.56       120

# %%
df_results.loc[len(df_results.index)] = ['KNN k=5 - Simple imputed', acc_knn_si, f1_knn_si]
df_results
# Out:
#                                   Model  Accuracy Score  Overall F1 Score
# 0        Decision Tree - Simple imputed        0.825000          0.810811
# 1             Decision Tree - KNN (k=1)        0.708333          0.684685
# 2             Decision Tree - KNN (k=2)        0.708333          0.732824
# 3             Decision Tree - KNN (k=3)        0.691667          0.733813
# 4  Logistic Regression - Simple imputed        0.725000          0.762590
# 5       Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6       Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7       Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8              KNN k=5 - Simple imputed        0.558333          0.576000

# %%
knn_knn1 = knn.fit(X_train_knn1, y_train_knn1)
y_pred_knn_knn1 = knn_knn1.predict(X_test_knn1)
acc_knn_knn1 = accuracy_score(y_test_knn1, y_pred_knn_knn1)
f1_knn_knn1 = f1_score(y_test_knn1, y_pred_knn_knn1)
print(classification_report(y_test_knn1, y_pred_knn_knn1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.53        62
#            1       0.55      0.69      0.61        58
#
#     accuracy                           0.57       120
#    macro avg       0.58      0.58      0.57       120
# weighted avg       0.58      0.57      0.57       120

# %%
df_results.loc[len(df_results.index)] = ['KNN k=5 - KNN (k=1)', acc_knn_knn1, f1_knn_knn1]
df_results
# Out:
#                                   Model  Accuracy Score  Overall F1 Score
# 0        Decision Tree - Simple imputed        0.825000          0.810811
# 1             Decision Tree - KNN (k=1)        0.708333          0.684685
# 2             Decision Tree - KNN (k=2)        0.708333          0.732824
# 3             Decision Tree - KNN (k=3)        0.691667          0.733813
# 4  Logistic Regression - Simple imputed        0.725000          0.762590
# 5       Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6       Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7       Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8              KNN k=5 - Simple imputed        0.558333          0.576000
# 9                   KNN k=5 - KNN (k=1)        0.575000          0.610687

# %%
knn_knn2 = knn.fit(X_train_knn2, y_train_knn2)
y_pred_knn_knn2 = knn_knn2.predict(X_test_knn2)
acc_knn_knn2 = accuracy_score(y_test_knn2, y_pred_knn_knn2)
f1_knn_knn2 = f1_score(y_test_knn2, y_pred_knn_knn2)
print(classification_report(y_test_knn2, y_pred_knn_knn2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.33      0.42        61
#            1       0.52      0.75      0.61        59
#
#     accuracy                           0.53       120
#    macro avg       0.54      0.54      0.51       120
# weighted avg       0.54      0.53      0.51       120

# %%
df_results.loc[len(df_results.index)] = ['KNN k=5 - KNN (k=2)', acc_knn_knn2, f1_knn_knn2]
df_results
# Out:
#                                    Model  Accuracy Score  Overall F1 Score
# 0         Decision Tree - Simple imputed        0.825000          0.810811
# 1              Decision Tree - KNN (k=1)        0.708333          0.684685
# 2              Decision Tree - KNN (k=2)        0.708333          0.732824
# 3              Decision Tree - KNN (k=3)        0.691667          0.733813
# 4   Logistic Regression - Simple imputed        0.725000          0.762590
# 5        Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6        Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7        Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8               KNN k=5 - Simple imputed        0.558333          0.576000
# 9                    KNN k=5 - KNN (k=1)        0.575000          0.610687
# 10                   KNN k=5 - KNN (k=2)        0.533333          0.611111

# %%
knn_knn3 = knn.fit(X_train_knn3, y_train_knn3)
y_pred_knn_knn3 = knn_knn3.predict(X_test_knn3)
acc_knn_knn3 = accuracy_score(y_test_knn3, y_pred_knn_knn3)
f1_knn_knn3 = f1_score(y_test_knn3, y_pred_knn_knn3)
print(classification_report(y_test_knn3, y_pred_knn_knn3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58        50
#            1       0.70      0.66      0.68        70
#
#     accuracy                           0.63       120
#    macro avg       0.63      0.63      0.63       120
# weighted avg       0.64      0.63      0.63       120

# %%
df_results.loc[len(df_results.index)] = ['KNN k=5 - KNN (k=3)', acc_knn_knn3, f1_knn_knn3]
df_results
# Out:
#                                    Model  Accuracy Score  Overall F1 Score
# 0         Decision Tree - Simple imputed        0.825000          0.810811
# 1              Decision Tree - KNN (k=1)        0.708333          0.684685
# 2              Decision Tree - KNN (k=2)        0.708333          0.732824
# 3              Decision Tree - KNN (k=3)        0.691667          0.733813
# 4   Logistic Regression - Simple imputed        0.725000          0.762590
# 5        Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6        Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7        Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8               KNN k=5 - Simple imputed        0.558333          0.576000
# 9                    KNN k=5 - KNN (k=1)        0.575000          0.610687
# 10                   KNN k=5 - KNN (k=2)        0.533333          0.611111
# 11                   KNN k=5 - KNN (k=3)        0.633333          0.676471

# %% [markdown]
# ## SVM Model

# %%
svc = SVC()

# %%
svm_si = svc.fit(X_train_si_data, y_train_si_data)
y_pred_svc_si = svm_si.predict(X_test_si_data)
acc_svc_si = accuracy_score(y_test_si_data, y_pred_svc_si)
f1_svc_si = f1_score(y_test_si_data, y_pred_svc_si)
print(classification_report(y_test_si_data, y_pred_svc_si))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.06      0.11        65
#            1       0.47      0.98      0.64        55
#
#     accuracy                           0.48       120
#    macro avg       0.63      0.52      0.37       120
# weighted avg       0.65      0.48      0.35       120

# %%
df_results.loc[len(df_results.index)] = ['SVM - Simple imputed', acc_svc_si, f1_svc_si]
df_results
# Out:
#                                    Model  Accuracy Score  Overall F1 Score
# 0         Decision Tree - Simple imputed        0.825000          0.810811
# 1              Decision Tree - KNN (k=1)        0.708333          0.684685
# 2              Decision Tree - KNN (k=2)        0.708333          0.732824
# 3              Decision Tree - KNN (k=3)        0.691667          0.733813
# 4   Logistic Regression - Simple imputed        0.725000          0.762590
# 5        Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6        Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7        Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8               KNN k=5 - Simple imputed        0.558333          0.576000
# 9                    KNN k=5 - KNN (k=1)        0.575000          0.610687
# 10                   KNN k=5 - KNN (k=2)        0.533333          0.611111
# 11                   KNN k=5 - KNN (k=3)        0.633333          0.676471
# 12                  SVM - Simple imputed        0.483333          0.635294

# %%
svm_knn1 = svc.fit(X_train_knn1, y_train_knn1)
y_pred_svc_knn1 = svm_knn1.predict(X_test_knn1)
acc_svc_knn1 = accuracy_score(y_test_knn1, y_pred_svc_knn1)
f1_svc_knn1 = f1_score(y_test_knn1, y_pred_svc_knn1)
print(classification_report(y_test_knn1, y_pred_svc_knn1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.06      0.12        62
#            1       0.50      0.98      0.66        58
#
#     accuracy                           0.51       120
#    macro avg       0.65      0.52      0.39       120
# weighted avg       0.65      0.51      0.38       120

# %%
df_results.loc[len(df_results.index)] = ['SVM - KNN (k=1)', acc_svc_knn1, f1_svc_knn1]
df_results
# Out:
#                                    Model  Accuracy Score  Overall F1 Score
# 0         Decision Tree - Simple imputed        0.825000          0.810811
# 1              Decision Tree - KNN (k=1)        0.708333          0.684685
# 2              Decision Tree - KNN (k=2)        0.708333          0.732824
# 3              Decision Tree - KNN (k=3)        0.691667          0.733813
# 4   Logistic Regression - Simple imputed        0.725000          0.762590
# 5        Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6        Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7        Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8               KNN k=5 - Simple imputed        0.558333          0.576000
# 9                    KNN k=5 - KNN (k=1)        0.575000          0.610687
# 10                   KNN k=5 - KNN (k=2)        0.533333          0.611111
# 11                   KNN k=5 - KNN (k=3)        0.633333          0.676471
# 12                  SVM - Simple imputed        0.483333          0.635294
# 13                       SVM - KNN (k=1)        0.508333          0.658960

# %%
svm_knn2 = svc.fit(X_train_knn2, y_train_knn2)
y_pred_svc_knn2 = svm_knn2.predict(X_test_knn2)
acc_svc_knn2 = accuracy_score(y_test_knn2, y_pred_svc_knn2)
f1_svc_knn2 = f1_score(y_test_knn2, y_pred_svc_knn2)
print(classification_report(y_test_knn2, y_pred_svc_knn2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.03      0.06        61
#            1       0.50      0.98      0.66        59
#
#     accuracy                           0.50       120
#    macro avg       0.58      0.51      0.36       120
# weighted avg       0.58      0.50      0.36       120

# %%
df_results.loc[len(df_results.index)] = ['SVM - KNN (k=2)', acc_svc_knn2, f1_svc_knn2]
df_results
# Out:
#                                    Model  Accuracy Score  Overall F1 Score
# 0         Decision Tree - Simple imputed        0.825000          0.810811
# 1              Decision Tree - KNN (k=1)        0.708333          0.684685
# 2              Decision Tree - KNN (k=2)        0.708333          0.732824
# 3              Decision Tree - KNN (k=3)        0.691667          0.733813
# 4   Logistic Regression - Simple imputed        0.725000          0.762590
# 5        Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6        Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7        Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8               KNN k=5 - Simple imputed        0.558333          0.576000
# 9                    KNN k=5 - KNN (k=1)        0.575000          0.610687
# 10                   KNN k=5 - KNN (k=2)        0.533333          0.611111
# 11                   KNN k=5 - KNN (k=3)        0.633333          0.676471
# 12                  SVM - Simple imputed        0.483333          0.635294
# 13                       SVM - KNN (k=1)        0.508333          0.658960
# 14                       SVM - KNN (k=2)        0.500000          0.659091

# %%
svm_knn3 = svc.fit(X_train_knn3, y_train_knn3)
y_pred_svc_knn3 = svm_knn3.predict(X_test_knn3)
acc_svc_knn3 = accuracy_score(y_test_knn3, y_pred_svc_knn3)
f1_svc_knn3 = f1_score(y_test_knn3, y_pred_svc_knn3)
print(classification_report(y_test_knn3, y_pred_svc_knn3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.04        50
#            1       0.58      0.99      0.73        70
#
#     accuracy                           0.58       120
#    macro avg       0.54      0.50      0.39       120
# weighted avg       0.55      0.58      0.44       120

# %%
df_results.loc[len(df_results.index)] = ['SVM - KNN (k=3)', acc_svc_knn3, f1_svc_knn3]
df_results
# Out:
#                                    Model  Accuracy Score  Overall F1 Score
# 0         Decision Tree - Simple imputed        0.825000          0.810811
# 1              Decision Tree - KNN (k=1)        0.708333          0.684685
# 2              Decision Tree - KNN (k=2)        0.708333          0.732824
# 3              Decision Tree - KNN (k=3)        0.691667          0.733813
# 4   Logistic Regression - Simple imputed        0.725000          0.762590
# 5        Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6        Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7        Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8               KNN k=5 - Simple imputed        0.558333          0.576000
# 9                    KNN k=5 - KNN (k=1)        0.575000          0.610687
# 10                   KNN k=5 - KNN (k=2)        0.533333          0.611111
# 11                   KNN k=5 - KNN (k=3)        0.633333          0.676471
# 12                  SVM - Simple imputed        0.483333          0.635294
# 13                       SVM - KNN (k=1)        0.508333          0.658960
# 14                       SVM - KNN (k=2)        0.500000          0.659091
# 15                       SVM - KNN (k=3)        0.583333          0.734043

# %% [markdown]
# ## Gradient Scores - Visual for :-
# ### 1. Decision Tree
# ### 2. Logistic Regression
# ### 3. KNN Model
# ### 4. SVM

# %%
df_results.style.background_gradient(cmap ="crest").set_properties(**{'font-size': '15px'})
# Out:
# <style type="text/css">
# #T_21d00_row0_col0, #T_21d00_row1_col0, #T_21d00_row2_col0, #T_21d00_row3_col0, #T_21d00_row4_col0, #T_21d00_row5_col0, #T_21d00_row6_col0, #T_21d00_row7_col0, #T_21d00_row8_col0, #T_21d00_row9_col0, #T_21d00_row10_col0, #T_21d00_row11_col0, #T_21d00_row12_col0, #T_21d00_row13_col0, #T_21d00_row14_col0, #T_21d00_row15_col0 {
#   font-size: 15px;
# }
# #T_21d00_row0_col1, #T_21d00_row0_col2 {
#   background-color: #2c3172;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row1_col1, #T_21d00_row2_col1 {
#   background-color: #1e6d8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row1_col2 {
#   background-color: #3a8b8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row2_col2 {
#   background-color: #1d6c8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row3_col1, #T_21d00_row5_col1 {
#   background-color: #22748b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row3_col2, #T_21d00_row15_col2 {
#   background-color: #1d6a8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row4_col1 {
#   background-color: #1c6488;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row4_col2 {
#   background-color: #205684;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row5_col2 {
#   background-color: #1e5b86;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row6_col1 {
#   background-color: #2a7c8c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row6_col2 {
#   background-color: #1f6f8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row7_col1 {
#   background-color: #1c6989;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row7_col2 {
#   background-color: #2a3f78;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row8_col1 {
#   background-color: #68af90;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row8_col2, #T_21d00_row12_col1 {
#   background-color: #a5cd90;
#   color: #000000;
#   font-size: 15px;
# }
# #T_21d00_row9_col1 {
#   background-color: #5da890;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row9_col2, #T_21d00_row10_col1 {
#   background-color: #7cb991;
#   color: #000000;
#   font-size: 15px;
# }
# #T_21d00_row10_col2 {
#   background-color: #7bb991;
#   color: #000000;
#   font-size: 15px;
# }
# #T_21d00_row11_col1 {
#   background-color: #3e8e8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row11_col2 {
#   background-color: #40908e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row12_col2 {
#   background-color: #61aa90;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row13_col1 {
#   background-color: #91c391;
#   color: #000000;
#   font-size: 15px;
# }
# #T_21d00_row13_col2, #T_21d00_row14_col2 {
#   background-color: #4c9b90;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_21d00_row14_col1 {
#   background-color: #98c691;
#   color: #000000;
#   font-size: 15px;
# }
# #T_21d00_row15_col1 {
#   background-color: #58a590;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# </style>
# <table id="T_21d00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21d00_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_21d00_level0_col1" class="col_heading level0 col1" >Accuracy Score</th>
#       <th id="T_21d00_level0_col2" class="col_heading level0 col2" >Overall F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21d00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21d00_row0_col0" class="data row0 col0" >Decision Tree - Simple imputed</td>
#       <td id="T_21d00_row0_col1" class="data row0 col1" >0.825000</td>
#       <td id="T_21d00_row0_col2" class="data row0 col2" >0.810811</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21d00_row1_col0" class="data row1 col0" >Decision Tree - KNN (k=1)</td>
#       <td id="T_21d00_row1_col1" class="data row1 col1" >0.708333</td>
#       <td id="T_21d00_row1_col2" class="data row1 col2" >0.684685</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21d00_row2_col0" class="data row2 col0" >Decision Tree - KNN (k=2)</td>
#       <td id="T_21d00_row2_col1" class="data row2 col1" >0.708333</td>
#       <td id="T_21d00_row2_col2" class="data row2 col2" >0.732824</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21d00_row3_col0" class="data row3 col0" >Decision Tree - KNN (k=3)</td>
#       <td id="T_21d00_row3_col1" class="data row3 col1" >0.691667</td>
#       <td id="T_21d00_row3_col2" class="data row3 col2" >0.733813</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21d00_row4_col0" class="data row4 col0" >Logistic Regression - Simple imputed</td>
#       <td id="T_21d00_row4_col1" class="data row4 col1" >0.725000</td>
#       <td id="T_21d00_row4_col2" class="data row4 col2" >0.762590</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_21d00_row5_col0" class="data row5 col0" >Logistic Regression - KNN (k=1)</td>
#       <td id="T_21d00_row5_col1" class="data row5 col1" >0.691667</td>
#       <td id="T_21d00_row5_col2" class="data row5 col2" >0.754967</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_21d00_row6_col0" class="data row6 col0" >Logistic Regression - KNN (k=2)</td>
#       <td id="T_21d00_row6_col1" class="data row6 col1" >0.675000</td>
#       <td id="T_21d00_row6_col2" class="data row6 col2" >0.727273</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_21d00_row7_col0" class="data row7 col0" >Logistic Regression - KNN (k=3)</td>
#       <td id="T_21d00_row7_col1" class="data row7 col1" >0.716667</td>
#       <td id="T_21d00_row7_col2" class="data row7 col2" >0.792683</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_21d00_row8_col0" class="data row8 col0" >KNN k=5 - Simple imputed</td>
#       <td id="T_21d00_row8_col1" class="data row8 col1" >0.558333</td>
#       <td id="T_21d00_row8_col2" class="data row8 col2" >0.576000</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_21d00_row9_col0" class="data row9 col0" >KNN k=5 - KNN (k=1)</td>
#       <td id="T_21d00_row9_col1" class="data row9 col1" >0.575000</td>
#       <td id="T_21d00_row9_col2" class="data row9 col2" >0.610687</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_21d00_row10_col0" class="data row10 col0" >KNN k=5 - KNN (k=2)</td>
#       <td id="T_21d00_row10_col1" class="data row10 col1" >0.533333</td>
#       <td id="T_21d00_row10_col2" class="data row10 col2" >0.611111</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_21d00_row11_col0" class="data row11 col0" >KNN k=5 - KNN (k=3)</td>
#       <td id="T_21d00_row11_col1" class="data row11 col1" >0.633333</td>
#       <td id="T_21d00_row11_col2" class="data row11 col2" >0.676471</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_21d00_row12_col0" class="data row12 col0" >SVM - Simple imputed</td>
#       <td id="T_21d00_row12_col1" class="data row12 col1" >0.483333</td>
#       <td id="T_21d00_row12_col2" class="data row12 col2" >0.635294</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_21d00_row13_col0" class="data row13 col0" >SVM - KNN (k=1)</td>
#       <td id="T_21d00_row13_col1" class="data row13 col1" >0.508333</td>
#       <td id="T_21d00_row13_col2" class="data row13 col2" >0.658960</td>
#     </tr>
#     <tr>
#       <th id="T_21d00_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_21d00_row14_col0" class="data row14 col0" >SVM - KNN (k=2)</td>
#       <td id="T_21d00_row14_col1" class="data row14 col1" >0.500000</td>
#       <td id="T_21d00_row14_col2" class="data row14 col2"

# %% [markdown]
# ## Decision Tree Classifier with Simple Imputed Data has the maximum 'Accuracy Score' as well as the maximum 'Overall F1 Score'.
# ### Accuracy Score = 82.5%
# ### Overall F1 Score = 81.08%
#
# ### ***For this classification problem, the KNN model would NOT be a good choice.
# ### ***Decision Tree and Logistic Regression give significantly better results than KNN or SVM

# %%
rf = RandomForestClassifier()

# %% [markdown]
# ## Random Forest Classifier
# ### Along with Hyper Parameter Tuning

# %%
param_grid = {"n_estimators":[10,50,100], "criterion":["gini","entropy"], "max_features":["auto","sqrt","log2"], "random_state":[4], "class_weight":["balanced"]}
rf_model = GridSearchCV(rf, param_grid, cv=5, scoring="f1")
rf_model.fit(X_train_si_data,y_train_si_data)
y_pred_rf = rf_model.predict(X_test_si_data)
print(classification_report(y_test_si_data,y_pred_rf))
print(rf_model.best_params_)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82        65
#            1       0.76      0.91      0.83        55
#
#     accuracy                           0.82       120
#    macro avg       0.83      0.83      0.82       120
# weighted avg       0.84      0.82      0.82       120
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'n_estimators': 100, 'random_state': 4}

# %%
param_grid = {"n_estimators":[70, 100, 130], "criterion":["gini","entropy"], "max_features":["auto", "sqrt", "log2"], "random_state":[4], "class_weight":["balanced"]}
rf_model = GridSearchCV(rf, param_grid, cv=5, scoring="f1")
rf_model.fit(X_train_si_data,y_train_si_data)
y_pred_rf = rf_model.predict(X_test_si_data)
print(classification_report(y_test_si_data,y_pred_rf))
print(rf_model.best_params_)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82        65
#            1       0.76      0.91      0.83        55
#
#     accuracy                           0.82       120
#    macro avg       0.83      0.83      0.82       120
# weighted avg       0.84      0.82      0.82       120
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'n_estimators': 130, 'random_state': 4}

# %%
param_grid = {"n_estimators":[100, 125, 150], "criterion":["gini","entropy"], "max_features":["auto", "sqrt", "log2"], "random_state":[4], "class_weight":["balanced"]}
rf_model = GridSearchCV(rf, param_grid, cv=5, scoring="f1")
rf_model.fit(X_train_si_data,y_train_si_data)
y_pred_rf = rf_model.predict(X_test_si_data)
print(classification_report(y_test_si_data,y_pred_rf))
print(rf_model.best_params_)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82        65
#            1       0.76      0.91      0.83        55
#
#     accuracy                           0.82       120
#    macro avg       0.83      0.83      0.82       120
# weighted avg       0.84      0.82      0.82       120
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'n_estimators': 125, 'random_state': 4}

# %%
param_grid = {"n_estimators":[115, 125, 135], "criterion":["gini","entropy"], "max_features":["auto", "sqrt", "log2"], "random_state":[4], "class_weight":["balanced"]}
rf_model = GridSearchCV(rf, param_grid, cv=5, scoring="f1")
rf_model.fit(X_train_si_data,y_train_si_data)
y_pred_rf = rf_model.predict(X_test_si_data)
print(classification_report(y_test_si_data,y_pred_rf))
print(rf_model.best_params_)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82        65
#            1       0.76      0.91      0.83        55
#
#     accuracy                           0.82       120
#    macro avg       0.83      0.83      0.82       120
# weighted avg       0.84      0.82      0.82       120
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'n_estimators': 125, 'random_state': 4}

# %%
acc_rf_si = accuracy_score(y_test_si_data, y_pred_rf)
f1_rf_si = f1_score(y_test_si_data, y_pred_rf)
acc_rf_si, f1_rf_si
# Out:
# (0.825, 0.8264462809917356)

# %%
df_results.loc[len(df_results.index)] = ['Random Forest', acc_rf_si, f1_rf_si]
df_results
# Out:
#                                    Model  Accuracy Score  Overall F1 Score
# 0         Decision Tree - Simple imputed        0.825000          0.810811
# 1              Decision Tree - KNN (k=1)        0.708333          0.684685
# 2              Decision Tree - KNN (k=2)        0.708333          0.732824
# 3              Decision Tree - KNN (k=3)        0.691667          0.733813
# 4   Logistic Regression - Simple imputed        0.725000          0.762590
# 5        Logistic Regression - KNN (k=1)        0.691667          0.754967
# 6        Logistic Regression - KNN (k=2)        0.675000          0.727273
# 7        Logistic Regression - KNN (k=3)        0.716667          0.792683
# 8               KNN k=5 - Simple imputed        0.558333          0.576000
# 9                    KNN k=5 - KNN (k=1)        0.575000          0.610687
# 10                   KNN k=5 - KNN (k=2)        0.533333          0.611111
# 11                   KNN k=5 - KNN (k=3)        0.633333          0.676471
# 12                  SVM - Simple imputed        0.483333          0.635294
# 13                       SVM - KNN (k=1)        0.508333          0.658960
# 14                       SVM - KNN (k=2)        0.500000          0.659091
# 15                       SVM - KNN (k=3)        0.583333          0.734043
# 16                         Random Forest        0.825000          0.826446

# %%
df_results.style.background_gradient(cmap ="crest").set_properties(**{'font-size': '15px'})
# Out:
# <style type="text/css">
# #T_8a2ad_row0_col0, #T_8a2ad_row1_col0, #T_8a2ad_row2_col0, #T_8a2ad_row3_col0, #T_8a2ad_row4_col0, #T_8a2ad_row5_col0, #T_8a2ad_row6_col0, #T_8a2ad_row7_col0, #T_8a2ad_row8_col0, #T_8a2ad_row9_col0, #T_8a2ad_row10_col0, #T_8a2ad_row11_col0, #T_8a2ad_row12_col0, #T_8a2ad_row13_col0, #T_8a2ad_row14_col0, #T_8a2ad_row15_col0, #T_8a2ad_row16_col0 {
#   font-size: 15px;
# }
# #T_8a2ad_row0_col1, #T_8a2ad_row16_col1, #T_8a2ad_row16_col2 {
#   background-color: #2c3172;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row0_col2 {
#   background-color: #2a3c77;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row1_col1, #T_8a2ad_row2_col1 {
#   background-color: #1e6d8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row1_col2 {
#   background-color: #3e8f8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row2_col2 {
#   background-color: #20728b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row3_col1, #T_8a2ad_row5_col1 {
#   background-color: #22748b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row3_col2, #T_8a2ad_row15_col2 {
#   background-color: #20718b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row4_col1, #T_8a2ad_row5_col2 {
#   background-color: #1c6488;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row4_col2 {
#   background-color: #1d5f87;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row6_col1 {
#   background-color: #2a7c8c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row6_col2 {
#   background-color: #23758b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row7_col1 {
#   background-color: #1c6989;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row7_col2 {
#   background-color: #26497e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row8_col1 {
#   background-color: #68af90;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row8_col2, #T_8a2ad_row12_col1 {
#   background-color: #a5cd90;
#   color: #000000;
#   font-size: 15px;
# }
# #T_8a2ad_row9_col1 {
#   background-color: #5da890;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row9_col2, #T_8a2ad_row10_col2 {
#   background-color: #7eba91;
#   color: #000000;
#   font-size: 15px;
# }
# #T_8a2ad_row10_col1 {
#   background-color: #7cb991;
#   color: #000000;
#   font-size: 15px;
# }
# #T_8a2ad_row11_col1 {
#   background-color: #3e8e8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row11_col2 {
#   background-color: #44948f;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row12_col2 {
#   background-color: #64ad90;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row13_col1 {
#   background-color: #91c391;
#   color: #000000;
#   font-size: 15px;
# }
# #T_8a2ad_row13_col2, #T_8a2ad_row14_col2 {
#   background-color: #509f90;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_8a2ad_row14_col1 {
#   background-color: #98c691;
#   color: #000000;
#   font-size: 15px;
# }
# #T_8a2ad_row15_col1 {
#   background-color: #58a590;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# </style>
# <table id="T_8a2ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a2ad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8a2ad_level0_col1" class="col_heading level0 col1" >Accuracy Score</th>
#       <th id="T_8a2ad_level0_col2" class="col_heading level0 col2" >Overall F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a2ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a2ad_row0_col0" class="data row0 col0" >Decision Tree - Simple imputed</td>
#       <td id="T_8a2ad_row0_col1" class="data row0 col1" >0.825000</td>
#       <td id="T_8a2ad_row0_col2" class="data row0 col2" >0.810811</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a2ad_row1_col0" class="data row1 col0" >Decision Tree - KNN (k=1)</td>
#       <td id="T_8a2ad_row1_col1" class="data row1 col1" >0.708333</td>
#       <td id="T_8a2ad_row1_col2" class="data row1 col2" >0.684685</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a2ad_row2_col0" class="data row2 col0" >Decision Tree - KNN (k=2)</td>
#       <td id="T_8a2ad_row2_col1" class="data row2 col1" >0.708333</td>
#       <td id="T_8a2ad_row2_col2" class="data row2 col2" >0.732824</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a2ad_row3_col0" class="data row3 col0" >Decision Tree - KNN (k=3)</td>
#       <td id="T_8a2ad_row3_col1" class="data row3 col1" >0.691667</td>
#       <td id="T_8a2ad_row3_col2" class="data row3 col2" >0.733813</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a2ad_row4_col0" class="data row4 col0" >Logistic Regression - Simple imputed</td>
#       <td id="T_8a2ad_row4_col1" class="data row4 col1" >0.725000</td>
#       <td id="T_8a2ad_row4_col2" class="data row4 col2" >0.762590</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8a2ad_row5_col0" class="data row5 col0" >Logistic Regression - KNN (k=1)</td>
#       <td id="T_8a2ad_row5_col1" class="data row5 col1" >0.691667</td>
#       <td id="T_8a2ad_row5_col2" class="data row5 col2" >0.754967</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8a2ad_row6_col0" class="data row6 col0" >Logistic Regression - KNN (k=2)</td>
#       <td id="T_8a2ad_row6_col1" class="data row6 col1" >0.675000</td>
#       <td id="T_8a2ad_row6_col2" class="data row6 col2" >0.727273</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8a2ad_row7_col0" class="data row7 col0" >Logistic Regression - KNN (k=3)</td>
#       <td id="T_8a2ad_row7_col1" class="data row7 col1" >0.716667</td>
#       <td id="T_8a2ad_row7_col2" class="data row7 col2" >0.792683</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8a2ad_row8_col0" class="data row8 col0" >KNN k=5 - Simple imputed</td>
#       <td id="T_8a2ad_row8_col1" class="data row8 col1" >0.558333</td>
#       <td id="T_8a2ad_row8_col2" class="data row8 col2" >0.576000</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8a2ad_row9_col0" class="data row9 col0" >KNN k=5 - KNN (k=1)</td>
#       <td id="T_8a2ad_row9_col1" class="data row9 col1" >0.575000</td>
#       <td id="T_8a2ad_row9_col2" class="data row9 col2" >0.610687</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8a2ad_row10_col0" class="data row10 col0" >KNN k=5 - KNN (k=2)</td>
#       <td id="T_8a2ad_row10_col1" class="data row10 col1" >0.533333</td>
#       <td id="T_8a2ad_row10_col2" class="data row10 col2" >0.611111</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8a2ad_row11_col0" class="data row11 col0" >KNN k=5 - KNN (k=3)</td>
#       <td id="T_8a2ad_row11_col1" class="data row11 col1" >0.633333</td>
#       <td id="T_8a2ad_row11_col2" class="data row11 col2" >0.676471</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8a2ad_row12_col0" class="data row12 col0" >SVM - Simple imputed</td>
#       <td id="T_8a2ad_row12_col1" class="data row12 col1" >0.483333</td>
#       <td id="T_8a2ad_row12_col2" class="data row12 col2" >0.635294</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8a2ad_row13_col0" class="data row13 col0" >SVM - KNN (k=1)</td>
#       <td id="T_8a2ad_row13_col1" class="data row13 col1" >0.508333</td>
#       <td id="T_8a2ad_row13_col2" class="data row13 col2" >0.658960</td>
#     </tr>
#     <tr>
#       <th id="T_8a2ad_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8a2ad_row14_col0" class="data row14 col0" >SVM - KNN (k=2)</td>
#       <td id="T_8a2ad_row14_col1" class="data row14 col1" >0.500000<

# %% [markdown]
# ## After implementing Random Forest classifier with hyper parameter tuning and Cross-Validation
#
# ### 1. We can see that both Decision Tree and Random Forest give the same accuracy score of 82.5%
# ### 2. The Overall F1 score is higher for Random Forest at 82.64% so, we would recommend to use Random Forest Classifier.
# ### 3. Although both Decision Tree and Random Forest models are good alternatives as compared to Logistic Regression, KNN and SVM.
